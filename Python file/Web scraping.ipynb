# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://livingliquidz.com/"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
headers={
    'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36 OPR/95.0.0.0'

}

# %%
final_data=[]

# %%
for page_number in range(1):
    url = 'https://livingliquidz.com/products/wines/domestic-wines/455'
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'lxml')
    
    wine_names = [wine.text for wine in soup.find_all('h4', class_='fw-500 m-0 text-dark ll-product-title')]
    bottle_size = [sizes.text for sizes in soup.find_all('button', class_='btn color-black p-0 fw-500 wbr-cmp-variation-view-toggle')]
    mrp = [m.text for m in soup.find_all('div', class_='wbr-amount fs-16')]
#     prices = [p.text for p in soup.find_all('div', class_='style_price-tag__cOxYc')]
#     urls = [ur.find('a')['href'] for ur in soup.find_all('div', class_='style_product-box__liepi')]
    
    for i in range(len(wine_names)):
        name = wine_names[i]
        size = bottle_size[i]
        price = mrp[0]
#         price = prices[i]
#         url = urls[i]
        
        final_data.append([name, size, mrp])

sampledf = pd.DataFrame(final_data, columns=['wine_name', 'size_of_the_bottle','mrp'])

# %%
sampledf
# Out:
#                              wine_name size_of_the_bottle  \
# 0                         AMARIS SYRAH             750ML
# 1                    AMARIS CHARDONNAY             750ML
# 2    AMARIS RESERVE CABERNET SAUVIGNON             750ML
# 3                AMARIS RESERVE MERLOT             750ML
# 4                  AMARIS RESERVE ROSE             750ML
# ..                                 ...                ...
# 157            YORK H BLOCK CHARDONNAY             750ML
# 158               YORK SAUVIGNON BLANC             750ML
# 159                        YORK SHIRAZ             750ML
# 160          YORK SPARKLING CUVEE BRUT             750ML
# 161       ZAMPA SOIREE BRUT MAGNIFIQUE             750ML
#
#                                                    mrp
# 0    [₹1290.00, ₹1400.00, ₹1450.00, ₹1600.00, ₹1400...
# 1    [₹1290.00, ₹1400.00, ₹1450.00, ₹1600.00, ₹1400...
# 2    [₹1290.00, ₹1400.00, ₹1450.00, ₹1600.00, ₹1400...
# 3    [₹1290.00, ₹1400.00, ₹1450.00, ₹1600.00, ₹1400...
# ...

# %%
boxes = soup.find_all("div", class_ = "card wbr-product-card h-100 rounded-20")
print(len (boxes))
# Out:
# 162

# %%
names = soup.find_all("h4",class_ = "fw-500 m-0 text-dark ll-product-title")

for i in names:
    print(i.text.strip())
# Out:
# AMARIS SYRAH
# AMARIS CHARDONNAY
# AMARIS RESERVE CABERNET SAUVIGNON
# AMARIS RESERVE MERLOT
# AMARIS RESERVE ROSE
# AMARIS RESERVE SANGIOVESE
# CASA VINO BLANCO
# CASA VINO ROSSO
# CHANDON BRUT
# CHANDON ROSE BRUT
# CHATEAU ROYAL LATE HARVEST CHENIN SYMPHONY
# CHATEAU ROYALE CABERNET SHIRAZ
# DESAAL CHENIN BLANC
# DESAAL SANGIOVESE
# DESAAL SHIRAZ
# FIGARO RED
# FIGARO WHITE
# FRATELLI CABERNET FRANC SHIRAZ
# FRATELLI CABERNET SAUVIGNON
# FRATELLI CHARDONNAY
# FRATELLI CHENIN BLANC
# FRATELLI CLASSIC CHENIN
# FRATELLI CLASSIC MERLOT
# FRATELLI CLASSIC SHIRAZ
# FRATELLI GRAN CUVEE
# FRATELLI KYRA CHENIN
# FRATELLI KYRA RED RESERVA
# FRATELLI MERLOT
# FRATELLI MS CHARDONNAY SAUVIGNON BLANC
# FRATELLI MS SANGIOVESE CABERNET SYRAH
# FRATELLI MS SANGIOVESE ROSE
# FRATELLI NOI SPARKLING
# FRATELLI NOI SPARKLING ROSE
# FRATELLI SANGIOVESE
# FRATELLI SANGIOVESE BIANCO
# FRATELLI SAUVIGNON BLANC
# FRATELLI SETTE
# FRATELLI SHIRAZ
# FRATELLI SHIRAZ ROSE
# FRATELLI SIDUS PORT WINE
# ...

# %%
mrp = soup.find_all("div",class_ = "wbr-amount fs-16")

for i in mrp:
    print(i.text.strip())
# Out:
# ₹1290.00
# ₹1400.00
# ₹1450.00
# ₹1600.00
# ₹1400.00
# ₹1400.00
# ₹330.00
# ₹330.00
# ₹2500.00
# ₹2500.00
# ₹995.00
# ₹1098.00
# ₹795.00
# ₹1150.00
# ₹1050.00
# ₹398.00
# ₹398.00
# ₹925.00
# ₹1000.00
# ₹880.00
# ₹750.00
# ₹625.00
# ₹750.00
# ₹650.00
# ₹1390.00
# ₹175.00
# ₹425.00
# ₹1050.00
# ₹1250.00
# ₹1250.00
# ₹1250.00
# ₹980.00
# ₹980.00
# ₹1050.00
# ₹900.00
# ₹775.00
# ₹2000.00
# ₹850.00
# ₹750.00
# ₹270.00
# ₹425.00
# ₹450.00
# ₹450.00
# ₹450.00
# ₹450.00
# ₹785.00
# ₹785.00
# ₹785.00
# ₹940.00
# ₹785.00
# ₹785.00
# ₹785.00
# ₹785.00
# ₹2200.00
# ₹2200.00
# ₹1175.00
# ₹2200.00
# ₹1175.00
# ₹1175.00
# ₹1175.00
# ₹1375.00
# ₹1475.00
# ₹1375.00
# ₹1425.00
# ₹1750.00
# ₹1750.00
# ₹4500.00
# ₹3000.00
# ₹3500.00
# ₹625.00
# ₹450.00
# ₹160.00
# ₹550.00
# ₹550.00
# ₹550.00
# ₹240.00
# ₹799.00
# ₹777.00
# ₹777.00
# ₹777.00
# ₹799.00
# ₹777.00
# ₹220.00
# ₹1950.00
# ₹1795.00
# ₹1595.00
# ₹755.00
# ₹260.00
# ₹260.00
# ₹365.00
# ₹365.00
# ₹775.00
# ₹1450.00
# ₹1550.00
# ₹995.00
# ₹750.00
# ...

# %%
bottle_size = soup.find_all("button",class_ = "btn color-black p-0 fw-500 wbr-cmp-variation-view-toggle")

for i in bottle_size:
    print(i.text.strip())
# Out:
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 375ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 250ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 330ML CAN
# 750ML
# 330ML CAN
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# ...

# %%
domesticwine=pd.DataFrame({'Name':names,'Price':mrp, 'Bottle size':bottle_size})

# %%
domesticwine
# Out:
#                                     Name           Price       Bottle size
# 0                         [AMARIS SYRAH]  [[₹], 1290.00]  [[750ML],  , []]
# 1                    [AMARIS CHARDONNAY]  [[₹], 1400.00]  [[750ML],  , []]
# 2    [AMARIS RESERVE CABERNET SAUVIGNON]  [[₹], 1450.00]  [[750ML],  , []]
# 3                [AMARIS RESERVE MERLOT]  [[₹], 1600.00]  [[750ML],  , []]
# 4                  [AMARIS RESERVE ROSE]  [[₹], 1400.00]  [[750ML],  , []]
# ..                                   ...             ...               ...
# 157            [YORK H BLOCK CHARDONNAY]   [[₹], 995.00]  [[750ML],  , []]
# 158               [YORK SAUVIGNON BLANC]   [[₹], 750.00]  [[750ML],  , []]
# 159                        [YORK SHIRAZ]   [[₹], 795.00]  [[750ML],  , []]
# 160          [YORK SPARKLING CUVEE BRUT]  [[₹], 1250.00]  [[750ML],  , []]
# 161       [ZAMPA SOIREE BRUT MAGNIFIQUE]  [[₹], 1475.00]  [[750ML],  , []]
#
# [162 rows x 3 columns]

# %%
url2="https://livingliquidz.com/products/imported/imported/460"

# %%
response = requests.get(url2, headers=headers)
soup = BeautifulSoup(response.text, 'lxml')

# %%
boxes1 = soup.find_all("div", class_ = "row g-0 m-0 h-100 align-items-center py-2")
print(len(boxes1))
# Out:
# 857

# %%
names1 = soup.find_all("h4",class_ = "fw-500 m-0 text-dark ll-product-title")

for i in names1:
    print(i.text.strip())
# Out:
# AMARIS MERLOT
# AMARIS PINOT GRIGIO
# AMARIS PINOT NOIR
# ARGENTO PINOT GRIGIO
# AMARIS RIESLING
# STORY TELLERS CHARDONNAY
# STORY TELLERS MERLOT
# 1959 GEWURZTRAMINER
# 1959 RIESLING
# 1959 SINGLE VARIETAL CABERNET SAUVIGNON
# 1959 SINGLE VARIETAL MERLOT
# 1959 SINGLE VARIETAL PINOT NOIR
# 1959 SINGLE VARIETAL SHIRAZ
# 29 CABERNET SAUVIGNON
# 9 LIVES CABERNET SAUVIGNON
# 9 LIVES CARMENERE
# 9 LIVES MERLOT
# 9 LIVES RIESLING
# 9 LIVES SAUVIGNON BLANC
# 958 SANTERO ICE MOSCATO DRY
# ACHELO CORTONA LA BRACC SYRAH
# AG CHARDONNAY
# AG MALBEC SHIRAZ
# AIX PROVENCE ROSE
# ALAMBRE MOSCATEL DE SETUBAL
# ALEXIS LECHINE SAINT EMILION
# ALLAN SCOTT BASE PINOT NOIR
# ALLAN SCOTT ESTATE SAUVIGNON BLANC
# ALLAN SCOTT FAMILY WINEMAKERS ROSE
# ALLAN SCOTT MARLBOROUGH PINOT NOIR
# ALLAN SCOTT MERLOT
# ALLEGRINI AMARONE DELLA VALPOLICELLA CLASSICO
# ALSACE GEWURZTRAMINER
# ALTER EGO RED WINE
# ANNAS WAY PINOT GRIS
# ANNAS WAY PINOT NOIR
# ANTARES CABERNET SAUVIGNON
# ANTARES CARMENERE
# ...

# %%
mrp1 = soup.find_all("div",class_ = "wbr-amount fs-16")

for i in mrp1:
    print(i.text.strip())
# Out:
# ₹2249.00
# ₹2249.00
# ₹2100.00
# ₹1850.00
# ₹2495.00
# ₹1600.00
# ₹1600.00
# ₹1825.00
# ₹1825.00
# ₹1695.00
# ₹1695.00
# ₹1825.00
# ₹1695.00
# ₹1970.00
# ₹2395.00
# ₹2350.00
# ₹2350.00
# ₹2295.00
# ₹2275.00
# ₹2750.00
# ₹3540.00
# ₹1595.00
# ₹1595.00
# ₹4195.00
# ₹1070.00
# ₹4900.00
# ₹5100.00
# ₹2575.00
# ₹3590.00
# ₹3950.00
# ₹2575.00
# ₹14500.00
# ₹4200.00
# ₹25000.00
# ₹3175.00
# ₹3295.00
# ₹1700.00
# ₹1700.00
# ₹1700.00
# ₹1700.00
# ₹1850.00
# ₹64794.00
# ₹2950.00
# ₹2995.00
# ₹2599.00
# ₹4865.00
# ₹3680.00
# ₹1950.00
# ₹1950.00
# ₹1950.00
# ₹1950.00
# ₹1895.00
# ₹1895.00
# ₹1895.00
# ₹1895.00
# ₹1895.00
# ₹1895.00
# ₹2090.00
# ₹2090.00
# ₹2940.00
# ₹9735.00
# ₹2904.00
# ₹9735.00
# ₹12570.00
# ₹3390.00
# ₹3300.00
# ₹2220.00
# ₹2310.00
# ₹3210.00
# ₹3100.00
# ₹3350.00
# ₹2100.00
# ₹2820.00
# ₹2250.00
# ₹4518.00
# ₹8299.00
# ₹7200.00
# ₹9999.00
# ₹2995.00
# ₹2995.00
# ₹2000.00
# ₹17399.00
# ₹2995.00
# ₹3300.00
# ₹3300.00
# ₹1950.00
# ₹2190.00
# ₹1950.00
# ₹1995.00
# ₹1995.00
# ...

# %%
bottle_size1 = soup.find_all("button",class_ = "btn color-black p-0 fw-500 wbr-cmp-variation-view-toggle")

for i in bottle_size1:
    print(i.text.strip())
# Out:
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 375ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# 750ML
# ...

# %%
importedwine=pd.DataFrame({'Name':names1,'Price':mrp1, 'Bottle size':bottle_size1})

# %%
importedwine
# Out:
#                                 Name            Price       Bottle size
# 0                    [AMARIS MERLOT]   [[₹], 2249.00]  [[750ML],  , []]
# 1              [AMARIS PINOT GRIGIO]   [[₹], 2249.00]  [[750ML],  , []]
# 2                [AMARIS PINOT NOIR]   [[₹], 2100.00]  [[750ML],  , []]
# 3             [ARGENTO PINOT GRIGIO]   [[₹], 1850.00]  [[750ML],  , []]
# 4                  [AMARIS RIESLING]   [[₹], 2495.00]  [[750ML],  , []]
# ..                               ...              ...               ...
# 852       [ZUCCARDI CONCRETO MALBEC]  [[₹], 10950.00]  [[750ML],  , []]
# 853           [ZUCCARDI JOSE MALBEC]  [[₹], 10950.00]  [[750ML],  , []]
# 854  [ZUCCARDI Q CABERNET SAUVIGNON]   [[₹], 5450.00]  [[750ML],  , []]
# 855        [ZUCCARDI SERIE A MALBEC]   [[₹], 3595.00]  [[750ML],  , []]
# 856      [ZUCCARDI SERIEA TORRONTES]   [[₹], 2950.00]  [[750ML],  , []]
#
# [857 rows x 3 columns]

# %%
url3="https://livingliquidz.com/products/domestic-beers/domestic-beers/868"

# %%
response = requests.get(url3, headers=headers)
soup = BeautifulSoup(response.text, 'lxml')

# %%
boxes2 = soup.find_all("div", class_ = "col-12 col-lg-6 px-3 py-2 p-lg-3")
print(len(boxes2))
# Out:
# 40

# %%
names2 = soup.find_all("h4",class_ = "fw-500 m-0 text-dark ll-product-title")

for i in names2:
    print(i.text.strip())
# Out:
# AMSTEL INTERNATIONAL STRONG BEER
# HEINEKEN INDIA LAGER
# KINGFISHER ULTRA WITBIER
# KINGFISHER ULTRA BEER
# KINGFISHER ULTRA MAX
# KINGFISHER PREMIUM BEER
# KINGFISHER STRONG
# LONDON PILSNER BEER
# LONDON PILSNER STRONG BEER
# HEINEKEN SILVER MALT LAGER
# BIRA BLONDE BEER
# BIRA BOOM
# BIRA GOLD STRONG
# BIRA IPA POMELO
# BIRA LIGHT BEER
# BIRA MALABAR STOUT
# BIRA RISE STRONG
# BIRA WHITE BEER
# BLUE MOON BELGIAN WHEAT ALE
# BRO CODE FRIZZANTE
# BUDWEISER GENUINE
# BUDWEISER MAGNUM STRONG
# CARLING STRONG BEER
# CARLSBERG ELEPHANT STRONG
# CARLSBERG SMOOTH BEER
# CORONA EXTRA PREMIUM BEER
# HAYWARDS 2000
# HOEGAARDEN WITBIER INDIAN
# HOEGAARDEN WITBIER NECTARINE
# HOEGAARDEN WITBIER ROSEE
# MILLER ACE STRONG
# MILLER HIGH LIFE BEER
# ROYAL CHALLENGE LAGER BEER
# ROYAL CHALLENGE STRONG
# THUNDERBOLT STRONG BEER
# TUBORG CLASSIC BLACK STRONG
# TUBORG GREEN BEER
# TUBORG ICE DRAFT
# TUBORG STRONG BEER
# TUBORG WHITE STRONG

# %%
mrp2 = soup.find_all("div",class_ = "wbr-amount fs-16")

for i in mrp2:
    print(i.text.strip())
# Out:
# ₹150.00
# ₹230.00
# ₹140.00
# ₹220.00
# ₹160.00
# ₹190.00
# ₹190.00
# ₹140.00
# ₹165.00
# ₹230.00
# ₹220.00
# ₹190.00
# ₹190.00
# ₹210.00
# ₹150.00
# ₹210.00
# ₹190.00
# ₹230.00
# ₹250.00
# ₹150.00
# ₹220.00
# ₹240.00
# ₹240.00
# ₹240.00
# ₹220.00
# ₹200.00
# ₹115.00
# ₹250.00
# ₹220.00
# ₹275.00
# ₹240.00
# ₹220.00
# ₹100.00
# ₹130.00
# ₹185.00
# ₹220.00
# ₹200.00
# ₹220.00
# ₹190.00
# ₹220.00

# %%
bottle_size2 = soup.find_all("button",class_ = "btn color-black p-0 fw-500 wbr-cmp-variation-view-toggle")

for i in bottle_size2:
    print(i.text.strip())
# Out:
# 500 ML CAN
# 650ML
# 330ML
# 650ML
# 330ML
# 650ML
# 650ML
# 650ML
# 650ML
# 650ML
# 650ML
# 650ML
# 500 ML CAN
# 500 ML CAN
# 330ML
# 500 ML CAN
# 500 ML CAN
# 650ML
# 500ML
# 375ML
# 650ML
# 650ML
# 650ML
# 650ML
# 650ML
# 330ML
# 500 ML CAN
# 500 ML CAN
# 330ML
# 500 ML CAN
# 650ML
# 650ML
# 500 ML CAN
# 500 ML CAN
# 650ML
# 650ML
# 650ML
# 650ML
# 650ML
# 650ML

# %%
domesticbeer=pd.DataFrame({'Name':names2,'Price':mrp2, 'Bottle size':bottle_size2})

# %%
domesticbeer
# Out:
#                                   Name          Price            Bottle size
# 0   [AMSTEL INTERNATIONAL STRONG BEER]  [[₹], 150.00]  [[500 ML CAN],  , []]
# 1               [HEINEKEN INDIA LAGER]  [[₹], 230.00]       [[650ML],  , []]
# 2           [KINGFISHER ULTRA WITBIER]  [[₹], 140.00]       [[330ML],  , []]
# 3              [KINGFISHER ULTRA BEER]  [[₹], 220.00]       [[650ML],  , []]
# 4               [KINGFISHER ULTRA MAX]  [[₹], 160.00]       [[330ML],  , []]
# 5            [KINGFISHER PREMIUM BEER]  [[₹], 190.00]       [[650ML],  , []]
# 6                  [KINGFISHER STRONG]  [[₹], 190.00]       [[650ML],  , []]
# 7                [LONDON PILSNER BEER]  [[₹], 140.00]       [[650ML],  , []]
# 8         [LONDON PILSNER STRONG BEER]  [[₹], 165.00]       [[650ML],  , []]
# 9         [HEINEKEN SILVER MALT LAGER]  [[₹], 230.00]       [[650ML],  , []]
# 10                  [BIRA BLONDE BEER]  [[₹], 220.00]       [[650ML],  , []]
# ...

# %%
url4="https://livingliquidz.com/products/international/international/877"

# %%
response = requests.get(url4, headers=headers)
soup = BeautifulSoup(response.text, 'lxml')

# %%
boxes3 = soup.find_all("div", class_ = "col-12 col-lg-6 px-3 py-2 p-lg-3")
print(len(boxes3))
# Out:
# 15

# %%
names3 = soup.find_all("h4",class_ = "fw-500 m-0 text-dark ll-product-title")

for i in names3:
    print(i.text.strip())
# Out:
# BREWDOG DEAD PONY CLUB
# BREWDOG HAZY JANE
# BREWDOG LOST LAGER
# BREWDOG PUNK IPA
# BUHO STRONG
# BUHO WITBIER
# COOPERS BEST EXTRA STOUT
# COOPERS ORIGINAL PALE ALE
# GUINNESS DRAUGHT BEER
# HOPPER BLONDE
# HOPPER WITBIER
# PERONI NASTRO AZZURRO
# SINGHA LAGER
# STANGEN IPA
# STANGEN WEISS BEER

# %%
mrp3 = soup.find_all("div",class_ = "wbr-amount fs-16")

for i in mrp3:
    print(i.text.strip())
# Out:
# ₹400.00
# ₹400.00
# ₹450.00
# ₹450.00
# ₹400.00
# ₹350.00
# ₹695.00
# ₹550.00
# ₹500.00
# ₹330.00
# ₹330.00
# ₹550.00
# ₹475.00
# ₹600.00
# ₹550.00

# %%
bottle_size3 = soup.find_all("button",class_ = "btn color-black p-0 fw-500 wbr-cmp-variation-view-toggle")

for i in bottle_size3:
    print(i.text.strip())
# Out:
# 330ML
# 330ML CAN
# 440ML CAN
# 330ML CAN
# 500 ML CAN
# 500 ML CAN
# 375ML
# 375ML
# 440ML CAN
# 330ML
# 330ML
# 330ML
# 330ML
# 500 ML CAN
# 500 ML CAN

# %%
importedbeer=pd.DataFrame({'Name':names3,'Price':mrp3, 'Bottle size':bottle_size3})

# %%
importedbeer
# Out:
#                            Name          Price            Bottle size
# 0      [BREWDOG DEAD PONY CLUB]  [[₹], 400.00]       [[330ML],  , []]
# 1           [BREWDOG HAZY JANE]  [[₹], 400.00]   [[330ML CAN],  , []]
# 2          [BREWDOG LOST LAGER]  [[₹], 450.00]   [[440ML CAN],  , []]
# 3            [BREWDOG PUNK IPA]  [[₹], 450.00]   [[330ML CAN],  , []]
# 4                 [BUHO STRONG]  [[₹], 400.00]  [[500 ML CAN],  , []]
# 5                [BUHO WITBIER]  [[₹], 350.00]  [[500 ML CAN],  , []]
# 6    [COOPERS BEST EXTRA STOUT]  [[₹], 695.00]       [[375ML],  , []]
# 7   [COOPERS ORIGINAL PALE ALE]  [[₹], 550.00]       [[375ML],  , []]
# 8       [GUINNESS DRAUGHT BEER]  [[₹], 500.00]   [[440ML CAN],  , []]
# 9               [HOPPER BLONDE]  [[₹], 330.00]       [[330ML],  , []]
# 10             [HOPPER WITBIER]  [[₹], 330.00]       [[330ML],  , []]
# 11      [PERONI NASTRO AZZURRO]  [[₹], 550.00]       [[330ML],  , []]
# ...

# %%
final_df = pd.concat([domesticwine, importedwine, domesticbeer, importedbeer], ignore_index=True)

# %%
final_df
# Out:
#                                      Name           Price  \
# 0                          [AMARIS SYRAH]  [[₹], 1290.00]
# 1                     [AMARIS CHARDONNAY]  [[₹], 1400.00]
# 2     [AMARIS RESERVE CABERNET SAUVIGNON]  [[₹], 1450.00]
# 3                 [AMARIS RESERVE MERLOT]  [[₹], 1600.00]
# 4                   [AMARIS RESERVE ROSE]  [[₹], 1400.00]
# ...                                   ...             ...
# 1069                     [HOPPER WITBIER]   [[₹], 330.00]
# 1070              [PERONI NASTRO AZZURRO]   [[₹], 550.00]
# 1071                       [SINGHA LAGER]   [[₹], 475.00]
# 1072                        [STANGEN IPA]   [[₹], 600.00]
# 1073                 [STANGEN WEISS BEER]   [[₹], 550.00]
#
#                 Bottle size
# 0          [[750ML],  , []]
# 1          [[750ML],  , []]
# 2          [[750ML],  , []]
# 3          [[750ML],  , []]
# 4          [[750ML],  , []]
# ...                     ...
# 1069       [[330ML],  , []]
# 1070       [[330ML],  , []]
# ...

# %%
final_df.to_csv('final.csv', index=False)
